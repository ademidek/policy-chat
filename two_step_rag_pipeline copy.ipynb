# %% [markdown]
# # Two Step Retrieval RAG Application with AWS Bedrock & ChromaDB (Cloud)
# ## Phase 1: Setup & Configuration
# This notebook covers the setup of dependencies, configuration of credentials, and initialization of AWS Bedrock and ChromaDB Cloud clients.

# %%
# Step 1: Install Dependencies
# Run once per fresh environment/kernel
# %pip -q install "chromadb>=0.5" boto3 sentence-transformers langchain-core
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Step 2: Configuration & Variables
import os
import chromadb
from chromadb.config import Settings

# --- AWS Configuration ---
# PLEASE REPLACE WITH YOUR ACTUAL CREDENTIALS
AWS_ACCESS_KEY_ID = "AKIAVFIWI7VEZTWFO7XK"
AWS_SECRET_ACCESS_KEY = "VQyTFeWxhmjPhZ5lDlLTRuir4YaWrRfp+Xr7omwC"
AWS_REGION = "us-east-1"

# Apply Environment Variables for Boto3
os.environ["AWS_ACCESS_KEY_ID"] = AWS_ACCESS_KEY_ID
os.environ["AWS_SECRET_ACCESS_KEY"] = AWS_SECRET_ACCESS_KEY
os.environ["AWS_DEFAULT_REGION"] = AWS_REGION

# --- Bedrock Model Configuration ---
# Using a stable Claude 3 Sonnet ID which is widely available in us-west-2
BEDROCK_MODEL_ID = "anthropic.claude-3-sonnet-20240229-v1:0"

# --- ChromaDB Cloud Configuration ---
# Sign up at https://trychroma.com to get your API Token
CHROMA_API_KEY = "ck-spmpTTkferWXYndpC8oa19kuaqRC4cRJNWgFsspdEAh"
CHROMA_TENANT = "default_tenant"  # Usually 'default_tenant' for most users
CHROMA_DATABASE = "rag_demo1" # Usually 'default_database'
CHROMA_COLLECTION_NAME = "two_step_rag_collection"

print("Configuration Loaded.")
# Out:
# Configuration Loaded.

# %%
# Step 3: Initialize Clients
import boto3
import chromadb

print("1. Initializing Boto3 Session...")
try:
    session = boto3.Session(
        aws_access_key_id=AWS_ACCESS_KEY_ID,
        aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
        region_name=AWS_REGION
    )
    bedrock_client = session.client("bedrock-runtime")
    print("   ✅ Bedrock Client Initialized successfully.")
except Exception as e:
    print(f"   ❌ Error initializing Bedrock: {e}")

print("\n2. Initializing ChromaDB Cloud Client...")
try:
    # Initialize CloudClient specifically for Chroma Cloud
    chroma_client = chromadb.CloudClient(
        tenant=CHROMA_TENANT,
        database=CHROMA_DATABASE,
        api_key=CHROMA_API_KEY
    )
    
    # Get or create the collection
    collection = chroma_client.get_or_create_collection(name=CHROMA_COLLECTION_NAME)
    print(f"   ✅ Connected to Chroma Cloud. Collection '{CHROMA_COLLECTION_NAME}' ready.")
    print(f"   ℹ️ Current Collection Count: {collection.count()}")
except Exception as e:
    print(f"   ❌ Error initializing ChromaDB Cloud: {e}")
# Out:
# 1. Initializing Boto3 Session...
#    ✅ Bedrock Client Initialized successfully.
#
# 2. Initializing ChromaDB Cloud Client...
#    ✅ Connected to Chroma Cloud. Collection 'two_step_rag_collection' ready.
#    ℹ️ Current Collection Count: 3058

# %% [markdown]
# ## Phase 2: Data Ingestion & Chunking
# We will read text files from the `files/` directory, chunk them using LangChain's `RecursiveCharacterTextSplitter`, save the chunks to `files/chunked/`, and verify the output.

# %%
# Step 4: Setup Directories (TXT)
import os
from pathlib import Path

# Prefer notebook's current working directory, but be explicit about what it resolves to
BASE_DIR = Path.cwd()
SOURCE_DIR = BASE_DIR / "Richmond_Policies_Cleaned"
CHUNKED_DIR = BASE_DIR / "chunked_output"

print("BASE_DIR =", BASE_DIR)
print("SOURCE_DIR =", SOURCE_DIR, "| exists:", SOURCE_DIR.exists())
print("CHUNKED_DIR =", CHUNKED_DIR)

CHUNKED_DIR.mkdir(parents=True, exist_ok=True)

# Debug: show what's inside SOURCE_DIR (top-level)
if SOURCE_DIR.exists():
    items = list(SOURCE_DIR.iterdir())
    print(f"\nItems in SOURCE_DIR ({len(items)}):")
    for p in items[:20]:
        print(" -", p.name, "(file)" if p.is_file() else "(dir)")
    if len(items) > 20:
        print(" ...")

# Collect txt files only
input_files = sorted([p.name for p in SOURCE_DIR.iterdir() if p.is_file() and p.suffix.lower() == ".txt"])

print(f"\n📄 Found {len(input_files)} txt file(s).")
for f in input_files[:10]:
    print(" -", f)
if len(input_files) > 10:
    print(" ...")
# Out:
# BASE_DIR = /Users/ademidek/Documents/GitHub/cognizant-ai-cohort/AI-ML-Learning--main/week-3-vector-databases-part1/assessments
# SOURCE_DIR = /Users/ademidek/Documents/GitHub/cognizant-ai-cohort/AI-ML-Learning--main/week-3-vector-databases-part1/assessments/Richmond_Policies_Cleaned | exists: True
# CHUNKED_DIR = /Users/ademidek/Documents/GitHub/cognizant-ai-cohort/AI-ML-Learning--main/week-3-vector-databases-part1/assessments/chunked_output
#
# Items in SOURCE_DIR (96):
#  - jury_duty_and_subpoenas_policy.txt (file)
#  - endowment_spending_policy.txt (file)
#  - policy_on_pregnancy_childbirth_lactation_and_related_conditions_faculty_and_staff1.txt (file)
#  - password_policy.txt (file)
#  - policy_on_provision_of_financial_resources_to_students.txt (file)
#  - course_level_policy.txt (file)
#  - bereavement_leave_policy.txt (file)
#  - policy_for_events_with_alcohol_on_campus.txt (file)
#  - alcohol_and_drug_policy.txt (file)
#  - policy_on_space_allocation_and_facilities_resources.txt (file)
#  - multiple_donor_gifts_policy.txt (file)
#  - general_data_privacy_regulation_notice.txt (file)
#  - policy_for_employment_of_out_of_state_residents.txt (file)
#  - non-retaliation_policy.txt (file)
#  - office_assignment_policy.txt (file)
#  - official_university_communications_policy.txt (file)
#  - placement_of_student_art_installations.txt (file)
#  - external_data_transfer_policy.txt (file)
#  - policy_on_prohibiting_and_responding_to_sexual_harassment_and_sexual_misconduct_students.txt (file)
#  - administrative_data_management_policy.txt (file)
#  ...
#
# 📄 Found 95 txt file(s).
#  - Statement_on_Free_Expression.txt
#  - academic_and_professional_preparation_requirements_for_faculty.txt
#  - academic_credit_policy.txt
#  - academic_integrity_monitoring.txt
#  - academic_progress_policy_as_bus_jepson.txt
#  - acceptable_use_policy.txt
#  - access_to_electronic_files_policy.txt
#  - additional_compensation_for_staff.txt
#  - administrative_data_management_policy.txt
#  - alcohol_and_drug_policy.txt
#  ...

# %%
# Step 5: Load, Semantic-Chunk, and Save Chunks (TXT)
import re
from typing import List
from pathlib import Path

def extract_text(file_path: str) -> str:
    with open(file_path, "r", encoding="utf-8", errors="ignore") as f:
        return f.read()

def sentence_chunking(text: str, sentences_per_chunk: int = 3, max_chunk_size: int = 1000) -> List[str]:
    sentences = re.split(r'(?<=[.!?])\s+', text.strip())
    sentences = [s.strip() for s in sentences if s.strip()]
    out, buf = [], []
    for s in sentences:
        if buf and (len(' '.join(buf)) + 1 + len(s) > max_chunk_size):
            out.append(' '.join(buf))
            buf = []
        buf.append(s)
        if len(buf) >= sentences_per_chunk:
            out.append(' '.join(buf))
            buf = []
    if buf:
        out.append(' '.join(buf))
    return out

def semantic_chunking(text: str, min_chunk_size: int = 100, max_chunk_size: int = 1000) -> List[str]:
    paragraphs = re.split(r'\n\n+', text)
    chunks, current_chunk, current_size = [], [], 0

    for para in paragraphs:
        para = para.strip()
        if not para:
            continue

        para_size = len(para)

        if para_size > max_chunk_size:
            if current_chunk:
                chunks.append('\n\n'.join(current_chunk))
                current_chunk, current_size = [], 0

            sub_chunks = sentence_chunking(para, sentences_per_chunk=3, max_chunk_size=max_chunk_size)
            chunks.extend(sub_chunks)

        elif current_size + para_size > max_chunk_size:
            if current_chunk:
                chunks.append('\n\n'.join(current_chunk))
            current_chunk = [para]
            current_size = para_size

        else:
            current_chunk.append(para)
            current_size += para_size

    if current_chunk:
        chunks.append('\n\n'.join(current_chunk))

    merged = []
    for ch in chunks:
        if merged and len(ch) < min_chunk_size:
            merged[-1] = merged[-1] + "\n\n" + ch
        else:
            merged.append(ch)
    return merged

total_chunks = 0
files_processed = 0
files_skipped_no_text = 0
first_written = None

for file_name in input_files:
    file_path = str(SOURCE_DIR / file_name)
    base_name = Path(file_name).stem

    if not os.path.isfile(file_path):
        print(f"❌ Missing file on disk: {file_path}")
        continue

    files_processed += 1
    text = extract_text(file_path)

    print(f"\n📄 {file_name}")
    print("   extracted text length:", len(text))
    print("   sample:", text[:200].replace("\n", " ") if text.strip() else "(EMPTY)")

    if not text.strip():
        print("   ⚠️ File is empty, skipping")
        files_skipped_no_text += 1
        continue

    chunks = semantic_chunking(text, min_chunk_size=150, max_chunk_size=1000)
    print("   chunks created:", len(chunks))

    # Save chunk files
    for i, chunk_content in enumerate(chunks, start=1):
        chunk_content = chunk_content.strip()
        if not chunk_content:
            continue

        chunk_filename = f"ch{i}-{base_name}-len{len(chunk_content)}.txt"
        chunk_path = str(CHUNKED_DIR / chunk_filename)

        with open(chunk_path, "w", encoding="utf-8") as cf:
            cf.write(chunk_content)

        if first_written is None:
            first_written = chunk_path

    total_chunks += len(chunks)

print("\n" + "="*60)
print("STEP 5 SUMMARY")
print("="*60)
print("files_processed:", files_processed)
print("files_skipped_no_text:", files_skipped_no_text)
print("total_chunks:", total_chunks)
print("first_written_chunk:", first_written)
print("CHUNKED_DIR:", str(CHUNKED_DIR))
# Out:
# 📄 Statement_on_Free_Expression.txt
#    extracted text length: 4324
#    sample: university of richmond statement on free expression approved december 17, 2020 by the board of trustees ins titutional mission the unive rsity of richmond is committed to the production and disseminat
#    chunks created: 7
#
# 📄 academic_and_professional_preparation_requirements_for_faculty.txt
#    extracted text length: 7058
#    sample: university of richmond | 1 university of richmond policy manual purpose: this policy is designed to ensure that faculty at the university of richmond have the highest quality preparation to accomplish
#    chunks created: 11
#
# 📄 academic_credit_policy.txt
#    extracted text length: 33107
#    sample: policy #: acd-1001 policy title: academic credit policy effective: 11/15/2024 responsible office: registrar's office date approved: 11/15/2024 approval: university faculty senate replaces policy dated
#    chunks created: 81
#
# 📄 academic_integrity_monitoring.txt
#    extracted text length: 5554
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to ensure regular and rigorous monitoring to support academic integrity, particularly with respec
#    chunks created: 10
#
# 📄 academic_progress_policy_as_bus_jepson.txt
#    extracted text length: 9493
#    sample: university of richmond | 1 university of richmond policy manual scope: this policy applies to undergraduate students enrolled in the school of arts & sciences, robins school of business, and jepson sc
#    chunks created: 16
#
# 📄 acceptable_use_policy.txt
#    extracted text length: 15538
#    sample: university of richmond | 1 university of richmond policy manual scope: this policy applies to the university of richmond and all of its affiliates. as used in this policy, the term "affiliates" means
#    chunks created: 39
#
# 📄 access_to_electronic_files_policy.txt
#    extracted text length: 10081
#    sample: university of richmond | 1 university of richmond policy manual purpose: the university of richmond respects the privacy of electronic communications in the same way that it respects the privacy of pa
#    chunks created: 21
#
# 📄 additional_compensation_for_staff.txt
#    extracted text length: 10665
#    sample: university of richmond | 1 university of richmond policy manual scope: this policy applies to the university of richmond and all of its affiliates. as used in this policy, the term "affiliates" means
#    chunks created: 23
#
# 📄 administrative_data_management_policy.txt
#    extracted text length: 21084
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to: 1. facilitate assignment of appropriate access to and responsibility for university data used
#    chunks created: 46
#
# 📄 alcohol_and_drug_policy.txt
#    extracted text length: 42040
#    sample: university of richmond | 1 university of richmond policy manual policy #: stu-1002 policy title: alcohol, tobacco and other drug policy effective: 08/15/2023 responsible office: compliance & title ix
#    chunks created: 88
#
# 📄 appointment_of_endowed_chairs.txt
#    extracted text length: 11529
#    sample: university of richmond | 1 university of richmond policy manual policy #: acd-7301 policy title: appointment of endowed chairs effective: 06/10/2022 responsible office: academic affairs date approved:
#    chunks created: 25
#
# 📄 benefits_for_10-month_staff_and_faculty_on_9-month_contracts.txt
#    extracted text length: 3067
#    sample: university of richmond | 1 university of richmond policy manual scope: this policy applies to the university of richmond and all of its affiliates. as used in this policy, the term "affiliates" means
#    chunks created: 6
#
# 📄 bereavement_leave_policy.txt
#    extracted text length: 3243
#    sample: university of richmond | 1 university of richmond policy manual purpose: the university of richmond recognizes the importance of family and the difficulty employees face following the loss of a loved
#    chunks created: 6
#
# 📄 board_of_trustees_conflict_of_interest_policy.txt
#    extracted text length: 27590
#    sample: university of richmond | 1 university of richmond policy manual purpose: by adoption of this conflict of interest policy, the board of trustees of the university of richmond (the "board") intends to f
#    chunks created: 43
#
# 📄 board_of_trustees_contract_approval_and_signature_authority.txt
#    extracted text length: 14439
#    sample: university of richmond | 1 university of richmond policy manual scope: this policy applies to the university of richmond and to its affiliates to the extent such affiliates are acting on behalf of the
#    chunks created: 29
#
# 📄 business_meals_policy.txt
#    extracted text length: 16160
#    sample: university of richmond | 1 university of richmond policy manual purpose: this policy is to provide guidance to individuals who are entertaining or incurring meal expenses on behalf of the university a
#    chunks created: 29
#
# 📄 campus_ministry_policy.txt
#    extracted text length: 9191
#    sample: university of richmond | 1 university of richmond policy manual scope: t his policy applies to the university of richmond and all of its affiliates. as used in this policy, the term "affiliates" means
#    chunks created: 16
#
# 📄 catering_minimums_policy.txt
#    extracted text length: 4995
#    sample: university of richmond | 1 university of richmond policy manual purpose: the implementation of a minimum order policy by university catering is designed to maximize resources, curate diverse and high-
#    chunks created: 10
#
# 📄 cell_phone-policy.txt
#    extracted text length: 6211
#    sample: university of richmond | 1 university of richmond policy manual purpose: this establishes the university policy on the procurement and purchase of work-related cellular phones and devices and the serv
#    chunks created: 13
#
# 📄 classroom_scheduling_policy.txt
#    extracted text length: 3473
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to support the most effective use of the university's classroom spaces, ensure that classes are a
#    chunks created: 7
#
# 📄 compliance_training_policy.txt
#    extracted text length: 2109
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to promote compliance with applicable laws and to set clear expectations for staff and faculty re
#    chunks created: 3
#
# 📄 contract_management_policy.txt
#    extracted text length: 16513
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to ensure that the university of richmond manages the risk associated with legal agreements and s
#    chunks created: 43
#
# 📄 course_level_policy.txt
#    extracted text length: 3433
#    sample: university of richmond | 1 university of richmond policy manual purpose: this purpose of this policy is to outline the ways in which course level is established when courses are approved. scope: this
#    chunks created: 8
#
# 📄 cybersecurity_incident_response_policy.txt
#    extracted text length: 11814
#    sample: university of richmond | 1 university of richmond policy manual purpose: the incident response policy provides the structure and processes required to effectively respond to an information security in
#    chunks created: 25
#
# 📄 data_security_policy.txt
#    extracted text length: 31392
#    sample: university of richmond | 1 university of richmond policy manual policy #: irm-4004 policy title: data security effective: 08/05/2024 responsible office: information services date approved: 08/05/2024
#    chunks created: 78
#
# 📄 delegation_of_approval_authority_and_processing_responsibilities.txt
#    extracted text length: 9874
#    sample: university of richmond | 1 university of richmond policy manual purpose: the university assigns responsibility for completing or approving business transactions and activities to employees based on th
#    chunks created: 16
#
# 📄 delegation_of_contract_approval_and_signature_authority_policy.txt
#    extracted text length: 31080
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to safeguard the financial integrity of the university by ensuring appropriate authorization and
#    chunks created: 36
#
# 📄 designation_of_emergency_personnel_policy.txt
#    extracted text length: 7205
#    sample: university of richmond | 1 university of richmond policy manual policy #: sec-2002 policy title: designation of personnel for emergencies effective: 10/01/2021 responsible office: office of emergency
#    chunks created: 14
#
# 📄 early_retirement_plan_for_staff_and_faculty_with_a_continuing_appointment.txt
#    extracted text length: 17844
#    sample: university of richmond | 1 university of richmond policy manual purpose: the university of richmond (the "university") has established this early retirement plan ("the plan") as an opportunity for cer
#    chunks created: 31
#
# 📄 effective_use_of_institutional_funds.txt
#    extracted text length: 6418
#    sample: university of richmond | 1 university of richmond policy manual purpose: the university of richmond is the beneficiary of many types of funds. in order to ensure the most effective use of university r
#    chunks created: 13
#
# 📄 electronic_card_access_policy.txt
#    extracted text length: 7853
#    sample: university of richmond | 1 university of richmond policy manual purpose: this policy is designed to ensure card access to various doors on campus are dependent upon need and appropriately maintained w
#    chunks created: 19
#
# 📄 electronic_signature_policy.txt
#    extracted text length: 7855
#    sample: university of richmond | 1 university of richmond policy manual purpose: this policy provides guidelines for the use of electronic signatures (as defined herein) at the university of richmond (the "un
#    chunks created: 14
#
# 📄 emergency_management_policy.txt
#    extracted text length: 12666
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to outline the roles and responsibilities for establishing and maintaining the university's emerg
#    chunks created: 25
#
# 📄 endowment_spending_policy.txt
#    extracted text length: 3100
#    sample: university of richmond | 1 policy #: fin-15001 policy title: endowment spending policy effective: 11/22/2019 responsible office: office of business affairs date approved: 11/22/2019 approval: board of
#    chunks created: 4
#
# 📄 external_data_transfer_policy.txt
#    extracted text length: 5084
#    sample: university of richmond | 1 university of richmond policy manual purpose: the university of richmond knows the importance of protecting the sensitive data that is entrusted to it. in order to fulfill t
#    chunks created: 13
#
# 📄 faculty_phased_retirement_plan.txt
#    extracted text length: 8496
#    sample: university of richmond | 1 university of richmond policy manual purpose: the university of richmond faculty phased retirement program (fprp) provides eligible, tenured faculty members with an option t
#    chunks created: 18
#
# 📄 film_and_media_screening_policy.txt
#    extracted text length: 3186
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to provide guidance to university employees and students about when to seek licensing for events
#    chunks created: 5
#
# 📄 financial_aid_code_of_conduct.txt
#    extracted text length: 13422
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to prohibit conflicts of interest relating to student financial aid and to establish standards of
#    chunks created: 26
#
# 📄 financial_conflict_of_interest_for_grant-funded_research.txt
#    extracted text length: 14420
#    sample: university of richmond | 1 university of richmond policy manual purpose: the university of richmond recognizes the need to protect the integrity of research and educational activities, and has adopted
#    chunks created: 25
#
# 📄 flexible_work_arrangement_policy.txt
#    extracted text length: 10609
#    sample: university of richmond | 1 university of richmond policy manual policy #: hrm-1002 policy title: flexible work arrangement policy effective: 05/26//2021 responsible office: human resources date approv
#    chunks created: 20
#
# 📄 fringe_rate_policy.txt
#    extracted text length: 3487
#    sample: university of richmond | 1 university of richmond policy manual scope: this policy applies to the university of richmond and all of its affiliates. as used in this policy, the term "affiliates" means
#    chunks created: 8
#
# 📄 general_data_privacy_regulation_notice.txt
#    extracted text length: 26971
#    sample: university of richmond | 1 university of richmond policy manual purpose: the university of richmond ("richmond") is committed to safeguarding the privacy of personal data. this policy is in response t
#    chunks created: 28
#
# 📄 gifts_and_gratuities_policy.txt
#    extracted text length: 3180
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of the gifts and gratuities policy is to direct university employees as to how to respond when presented with a gif
#    chunks created: 6
#
# 📄 gifts_prizes_and_awards_policy.txt
#    extracted text length: 8274
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to provide guidance to individuals who wish to provide gifts, prizes, or awards utilizing funds a
#    chunks created: 15
#
# 📄 hazing_policy.txt
#    extracted text length: 12516
#    sample: university of richmond | 1 university of richmond policy manual purpose: this policy sets forth the university's prohibition of hazing, as defined herein. this policy is designed to foster compliance
#    chunks created: 23
#
# 📄 health_and_imunization_record_policy.txt
#    extracted text length: 3522
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to articulate a formal policy regarding health entrance requirements to ensure the necessary info
#    chunks created: 7
#
# 📄 hipaa_policy.txt
#    extracted text length: 28367
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to ensure that the university of richmond complies with the health insurance portability and acco
#    chunks created: 78
#
# 📄 holiday_leave_policy.txt
#    extracted text length: 7129
#    sample: university of richmond | 1 university of richmond policy manual scope: this policy applies to the university of richmond employees and all of its affiliates. as used in this policy, the term "employee
#    chunks created: 16
#
# 📄 identity_and_access_management_policy.txt
#    extracted text length: 15969
#    sample: university of richmond | 1 university of richmond policy manual purpose: to establish a framework that facilitates appropriate access by authorized individuals and entities to university electronic sy
#    chunks created: 38
#
# 📄 inclement_weather_policy.txt
#    extracted text length: 6246
#    sample: university of richmond | 1 university of richmond policy manual purpose: this policy describes the different situations under which the regular on campus operating schedule may be modified due to incl
#    chunks created: 13
#
# 📄 inclement_weather_time_reporting_and_pay_policy.txt
#    extracted text length: 6347
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to provide clarity on university payment during inclement weather days for both essential and non
#    chunks created: 12
#
# 📄 indirect_costs_recovery_policy.txt
#    extracted text length: 3771
#    sample: university of richmond | 1 university of richmond policy manual scope: this policy applies to the university of richmond and all of its affiliates. as used in this policy, the term "affiliates" means
#    chunks created: 8
#
# 📄 information_security_policy.txt
#    extracted text length: 9113
#    sample: university of richmond | 1 university of richmond policy manual purpose: this policy and related standards define the framework upon which the university of richmond's [the "university"] information s
#    chunks created: 18
#
# 📄 intellectual_property_policy.txt
#    extracted text length: 37429
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to set forth the procedure for timely identification, commercial development and protection of fa
#    chunks created: 82
#
# 📄 international_travel_policy.txt
#    extracted text length: 9372
#    sample: university of richmond | 1 university of richmond policy manual purpose: this policy addresses the health and safety of university of richmond (ur) students during university sponsored international t
#    chunks created: 17
#
# 📄 joint_ventures_policy.txt
#    extracted text length: 4015
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy on joint ventures with third parties is to protect and further the charitable purposes for which the
#    chunks created: 10
#
# 📄 jury_duty_and_subpoenas_policy.txt
#    extracted text length: 1991
#    sample: university of richmond | 1 university of richmond policy manual scope: this policy applies to the university of richmond employees and all of its affiliates. as used in this policy, the term "employee
#    chunks created: 4
#
# 📄 lock_and_key_management_policy.txt
#    extracted text length: 13842
#    sample: university of richmond | 1 university of richmond policy manual purpose: this policy is designed to ensure effective control, security, and management of the university's lock and key system for the s
#    chunks created: 34
#
# 📄 military_leave_policy.txt
#    extracted text length: 2212
#    sample: university of richmond | 1 university of richmond policy manual scope: this policy applies to the university of richmond and all of its affiliates. as used in this policy, the term "affiliates" means
#    chunks created: 4
#
# 📄 multiple_donor_gifts_policy.txt
#    extracted text length: 4065
#    sample: university of richmond | 1 university of richmond policy manual purpose: it is not uncommon for donors to pool together their resources to create a group gift, often in memory or honor of a particular
#    chunks created: 7
#
# 📄 museum_collections_management_policy.txt
#    extracted text length: 32301
#    sample: university of richmond | 1 university of richmond policy manual purpose: the university of richmond collections management policy is intended to provide a framework to ensure that the items held by th
#    chunks created: 62
#
# 📄 nepotism_and_personal_relationship_policy.txt
#    extracted text length: 2712
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to avoid favoritism, the appearance of or potential for favoritism, and conflicts of interest oft
#    chunks created: 4
#
# 📄 network_device_connectivity_policy.txt
#    extracted text length: 7548
#    sample: university of richmond | 1 university of richmond policy manual scope: this policy applies to the university of richmond and all of its affiliates. as used in this policy, the term "affiliates" means
#    chunks created: 16
#
# 📄 non-retaliation_policy.txt
#    extracted text length: 2838
#    sample: university of richmond | 1 university of richmond policy manual purpose: this policy is designed to foster the university of richmond's commitment to compliance with applicable laws and regulations go
#    chunks created: 4
#
# 📄 office_assignment_policy.txt
#    extracted text length: 9367
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to ensure that university office space is used as effectively as possible to advance the universi
#    chunks created: 19
#
# 📄 official_university_communications_policy.txt
#    extracted text length: 1636
#    sample: university of richmond | 1 university of richmond policy manual scope: this policy applies to the university of richmond and all of its affiliates. as used in this policy, the term "affiliates" means
#    chunks created: 4
#
# 📄 outdoor_grill_use_policy.txt
#    extracted text length: 5546
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to provide guidelines for students, faculty, and staff to engage in safe use of university of ric
#    chunks created: 13
#
# 📄 parental_leave_policy.txt
#    extracted text length: 7032
#    sample: university of richmond | 1 university of richmond policy manual purpose: in recognition of the university's commitment to the welfare of its employees and their families, this parental leave policy pr
#    chunks created: 14
#
# 📄 password_policy.txt
#    extracted text length: 7287
#    sample: university of richmond | 1 university of richmond policy manual purpose: the university of richmond is committed to a secure information technology environment in support of its mission. many systems
#    chunks created: 17
#
# 📄 photography_and_videography_policy.txt
#    extracted text length: 5281
#    sample: university of richmond | 1 university of richmond policy manual scope: this policy applies to the university of richmond and all space owned or leased by the university, including both indoor and outd
#    chunks created: 9
#
# 📄 placement_of_student_art_installations.txt
#    extracted text length: 5165
#    sample: university of richmond | 1 university of richmond policy manual scope: this policy applies to the university of richmond and all of its affiliates. as used in this policy, the term "affiliates" means
#    chunks created: 7
#
# 📄 policy_and_procedure_on_monetary_support_and_cash_donations.txt
#    extracted text length: 8205
#    sample: university of richmond | 1 university of richmond policy manual purpose: as a non-profit institution, the university of richmond must exercise good stewardship of its charitable assets and must ensure
#    chunks created: 14
#
# 📄 policy_for_employment_of_out_of_state_residents.txt
#    extracted text length: 10079
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to establish the framework for hiring or reassigning university of richmond employees to perform
#    chunks created: 20
#
# 📄 policy_for_events_with_alcohol_on_campus.txt
#    extracted text length: 17920
#    sample: university of richmond | 1 university of richmond policy manual purpose: all members of the university community and third-party users of university facilities are responsible for knowing and acting i
#    chunks created: 49
#
# 📄 policy_for_responding_to_allegations_of_research_misconduct.txt
#    extracted text length: 71319
#    sample: university of richmond | 1 university of richmond policy manual purpose: the university of richmond expects adherence to the highest ethical and moral standards in the conduct of research and scholarl
#    chunks created: 125
#
# 📄 policy_on_business_expenses_and_compensation.txt
#    extracted text length: 4762
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to provide clarity about the distinction between funds to support business expenses and funds pai
#    chunks created: 9
#
# 📄 policy_on_campus_protests_and_demonstrations.txt
#    extracted text length: 12617
#    sample: university of richmond | 1 university of richmond policy manual purpose: the mission of the university of richmond is to educate in an academically challenging, intellectually vibrant, and collaborati
#    chunks created: 18
#
# 📄 policy_on_creating_suspending_eliminating_programs.txt
#    extracted text length: 24436
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to ensure that all proposed changes to academic programs are thoroughly reviewed by the faculty a
#    chunks created: 45
#
# 📄 policy_on_emeritus_status.txt
#    extracted text length: 2521
#    sample: university of richmond | 1 university of richmond policy manual purpose: this policy provides clarity as to the benefits associated with emeritus status. scope: this policy applies to the university o
#    chunks created: 6
#
# 📄 policy_on_policies.txt
#    extracted text length: 5666
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to outline the ways in which the university will develop, approve, revise, and distribute policie
#    chunks created: 9
#
# 📄 policy_on_political_campaign_activity_on_campus.txt
#    extracted text length: 19454
#    sample: university of richmond | 1 university of richmond policy manual purpose: this policy is designed to ensure that the university of richmond complies with applicable laws and regulations regarding polit
#    chunks created: 44
#
# 📄 policy_on_pregnancy_childbirth_lactation_and_related_conditions_faculty_and_staff1.txt
#    extracted text length: 7654
#    sample: university of richmond | 1 university of richmond policy manual purpose: this policy is designed to foster adherence to the university of richmond's commitment to non- discrimination and to ensure com
#    chunks created: 13
#
# 📄 policy_on_prohibiting_and_responding_to_sex_discrimination_faculty_staff.txt
#    extracted text length: 55116
#    sample: university of richmond |page 1 university of richmond policy manual policy #: gov-3107 policy title: policy on prohibiting and responding to sex discrimination - faculty and staff effective: 07/01/202
#    chunks created: 130
#
# 📄 policy_on_prohibiting_and_responding_to_sex_discrimination_students.txt
#    extracted text length: 54182
#    sample: university of richmond |page 1 university of richmond policy manual policy #: gov-3108 policy title: policy on prohibiting and responding to sex discrimination - students effective: 7/01/2025 responsi
#    chunks created: 130
#
# 📄 policy_on_prohibiting_and_responding_to_sexual_harassment_and_sexual_misconduct_faculty_staff.txt
#    extracted text length: 117355
#    sample: university of richmond | 1 purpose: this policy is designed to foster compliance with title ix of the education amendments of 1972 (title ix), title vii of the civil rights act of 1964 (title vii), ot
#    chunks created: 301
#
# 📄 policy_on_prohibiting_and_responding_to_sexual_harassment_and_sexual_misconduct_students.txt
#    extracted text length: 92088
#    sample: university of richmond | 1 purpose: this policy is designed to foster compliance with title ix of the education amendments of 1972 (title ix), other applicable laws, and the university of richmond's p
#    chunks created: 227
#
# 📄 policy_on_protecting_student_privacy_in_distance_education.txt
#    extracted text length: 4341
#    sample: university of richmond | 1 university of richmond policy manual purpose: the university of richmond is committed to protecting student privacy for students enrolled in distance education courses. scop
#    chunks created: 8
#
# 📄 policy_on_provision_of_financial_resources_to_students.txt
#    extracted text length: 9550
#    sample: university of richmond | 1 university of richmond policy manual purpose: the purpose of this policy is to ensure that the university of richmond can support students in need of financial assistance wh
#    chunks created: 18
#
# 📄 policy_on_space_allocation_and_facilities_resources.txt
#    extracted text length: 25432
#    sample: university of richmond | 1 university of richmond policy manual purpose: space is a vital resource for the university of richmond. the purpose of this policy is to ensure that space and university fac
#    chunks created: 45
#
# 📄 policy_prohibiting_and_responding_to_discrimination_based_on_protected_status_faculty_staff.txt
#    extracted text length: 50385
#    sample: university of richmond |page 1 university of richmond policy manual policy #: gov-3106 policy title: policy prohibiting and responding to discrimination based on protected status- faculty and staff ef
#    chunks created: 121
#
# 📄 policy_prohibiting_and_responding_to_discrimination_based_on_protected_status_students.txt
#    extracted text length: 49985
#    sample: university of richmond |page 1 university of richmond policy manual policy #: gov-3102 policy title: policy prohibiting and responding to discrimination based on protected status- students effective:
#    chunks created: 118
#
# 📄 policy_prohibiting_discrimination.txt
#    extracted text length: 14304
#    sample: university of richmond | 1 university of richmond policy manual purpose: this policy is designed to foster adherence to the university of richmond's commitment to non-discrimination and to ensure comp
#    chunks created: 24
#
# 📄 policy_prohibiting_firearms_on_campus.txt
#    extracted text length: 3782
#    sample: university of richmond | 1 university of richmond policy manual purpose: the university of richmond fosters an environment to promote a safe, secure, and inclusive campus community and an appropriate
#    chunks created: 8
#
# 📄 space_taxonomy.txt
#    extracted text length: 1865
#    sample: university of richmond space taxonomy reference: prm-1002 policy on space allocation and facilities resources building category space steward priority use contact (if other than steward) scheduling cl
#    chunks created: 2
#
# 📄 use_of_university_owned_houses.txt
#    extracted text length: 8283
#    sample: university of richmond | 1 university of richmond policy manual purpose: the university's policy for the management and use of university-owned houses is intended to establish a framework for ensuring
#    chunks created: 15
#
# ============================================================
# STEP 5 SUMMARY
# ============================================================
# files_processed: 95
# files_skipped_no_text: 0
# total_chunks: 3058
# first_written_chunk: /Users/ademidek/Documents/GitHub/cognizant-ai-cohort/AI-ML-Learning--main/week-3-vector-databases-part1/assessments/chunked_output/ch1-Statement_on_Free_Expression-len989.txt
# CHUNKED_DIR: /Users/ademidek/Documents/GitHub/cognizant-ai-cohort/AI-ML-Learning--main/week-3-vector-databases-part1/assessments/chunked_output

# %%
# Step 6: Verify a Sample Chunk
import os, random

chunk_files = [f for f in os.listdir(CHUNKED_DIR) if f.lower().endswith(".txt")]
print(f"Found {len(chunk_files)} chunk file(s).")

if chunk_files:
    sample = random.choice(chunk_files)
    print("\n--- Sample chunk file:", sample, "---\n")
    with open(os.path.join(CHUNKED_DIR, sample), "r", encoding="utf-8", errors="ignore") as f:
        txt = f.read()
    print(txt[:1200])
    if len(txt) > 1200:
        print("\n... (truncated)")
else:
    print("No chunks found. Check SOURCE_DIR and Step 5.")
# Out:
# Found 3058 chunk file(s).
#
# --- Sample chunk file: ch277-policy_on_prohibiting_and_responding_to_sexual_harassment_and_sexual_misconduct_faculty_staff-len267.txt ---
#
# g. initial notification to the parties. after deliberations on the issue of responsibility are completed, the
# hearing officer shall meet separately with the respondent and complainant to notify them of the
# decision of the hearing board on the issue of responsibility.

# %% [markdown]
# ## Phase 3: Embeddings & Vector Store
# We will now read the chunked files we just created, generate embeddings (handled automatically by Chroma's default embedding function), and upsert them into the ChromaDB Cloud collection.
#
# > **Note:** We are using ChromaDB's default embedding model (`all-MiniLM-L6-v2`) which is built into the client. No extra API calls to Bedrock are needed for *embedding* in this setup, saving costs.

# %%
# Step 7: Prepare Data (documents, metadatas, ids) from chunk files
import uuid
import os

chunk_files = sorted([f for f in os.listdir(CHUNKED_DIR) if f.lower().endswith(".txt")])

documents, metadatas, ids = [], [], []

def parse_chunk_filename(file_name: str):
    """Parse 'ch{idx}-{base}-len{N}.txt'"""
    name_no_ext = os.path.splitext(file_name)[0]
    parts = name_no_ext.split("-")
    chunk_part = None
    char_len = None
    file_base = None
    try:
        chunk_part = int(parts[0].replace("ch",""))
        char_len = int(parts[-1].replace("len",""))
        file_base = "-".join(parts[1:-1])  # base name may contain hyphens
    except Exception:
        file_base = name_no_ext
    return chunk_part, file_base, char_len

for fn in chunk_files:
    p = os.path.join(CHUNKED_DIR, fn)
    with open(p, "r", encoding="utf-8", errors="ignore") as f:
        content = f.read().strip()
    if not content:
        continue

    chunk_part, file_base, char_len = parse_chunk_filename(fn)

    documents.append(content)
    metadatas.append({
        "source": fn,               # the chunk filename
        "file_name": file_base,     # the original doc base name
        "chunk_part": chunk_part,
        "char_len": char_len if char_len is not None else len(content),
    })
    ids.append(str(uuid.uuid4()))

print(f"✅ Prepared {len(documents)} chunks for vector upsert.")
print("Sample metadata:", metadatas[0] if metadatas else None)
# Out:
# ✅ Prepared 3058 chunks for vector upsert.
# Sample metadata: {'source': 'ch1-Statement_on_Free_Expression-len989.txt', 'file_name': 'Statement_on_Free_Expression', 'chunk_part': 1, 'char_len': 989}

# %%
# Step 8: Add to ChromaDB (Embed & Upsert)
from chromadb.utils import embedding_functions

embedding_fn = embedding_functions.SentenceTransformerEmbeddingFunction(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# delete + recreate to avoid embedding function conflict
try:
    chroma_client.delete_collection(CHROMA_COLLECTION_NAME)
    print("🗑️ Deleted existing collection:", CHROMA_COLLECTION_NAME)
except Exception:
    pass

chroma_client = chromadb.CloudClient(
    api_key=CHROMA_API_KEY,
    tenant=CHROMA_TENANT,
    database=CHROMA_DATABASE,
)

collection = chroma_client.get_or_create_collection(
    name=CHROMA_COLLECTION_NAME,
    embedding_function=embedding_fn,
    metadata={"hnsw:space": "cosine"},
)

BATCH_SIZE = 128
for i in range(0, len(documents), BATCH_SIZE):
    j = i + BATCH_SIZE
    if hasattr(collection, "upsert"):
        collection.upsert(
            ids=ids[i:j],
            documents=documents[i:j],
            metadatas=metadatas[i:j],
        )
    else:
        collection.add(
            ids=ids[i:j],
            documents=documents[i:j],
            metadatas=metadatas[i:j],
        )
    print(f"✅ Uploaded {min(j, len(documents))}/{len(documents)}")

print("🎉 Upload complete.")
# Out:
# 🗑️ Deleted existing collection: two_step_rag_collection
# ✅ Uploaded 128/3058
# ✅ Uploaded 256/3058
# ✅ Uploaded 384/3058
# ✅ Uploaded 512/3058
# ✅ Uploaded 640/3058
# ✅ Uploaded 768/3058
# ✅ Uploaded 896/3058
# ✅ Uploaded 1024/3058
# ✅ Uploaded 1152/3058
# ✅ Uploaded 1280/3058
# ✅ Uploaded 1408/3058
# ✅ Uploaded 1536/3058
# ✅ Uploaded 1664/3058
# ✅ Uploaded 1792/3058
# ✅ Uploaded 1920/3058
# ✅ Uploaded 2048/3058
# ✅ Uploaded 2176/3058
# ✅ Uploaded 2304/3058
# ✅ Uploaded 2432/3058
# ✅ Uploaded 2560/3058
# ✅ Uploaded 2688/3058
# ✅ Uploaded 2816/3058
# ✅ Uploaded 2944/3058
# ✅ Uploaded 3058/3058
# 🎉 Upload complete.

# %%
# Step 9: Verify Embedding with a Test Query
test_q = "visitation policy"
results = collection.query(
    query_texts=[test_q],
    n_results=3,
    include=["documents", "metadatas", "distances"]
)

print(f"Query: {test_q}")
for i,(doc,meta,dist) in enumerate(zip(results["documents"][0], results["metadatas"][0], results["distances"][0]), start=1):
    print(f"\nResult {i}: distance={dist:.4f} | file={meta.get('file_name')} | chunk={meta.get('chunk_part')}")
    print(doc[:400] + ("..." if len(doc)>400 else ""))
# Out:
# Query: visitation policy
#
# Result 1: distance=0.5022 | file=parental_leave_policy | chunk=12
# policy background
# policy for staff and faculty combined and updated effective january 1, 2025. policy was reviewed by
# president's cabinet and academic cabinet prior to approval on november 12, 2024. staff parental leave policy:
# established july 1, 2009 following review by president's cabinet and deans.
#
# Result 2: distance=0.5216 | file=parental_leave_policy | chunk=2
# policy statement:
# as outlined in this policy, the university of richmond provides parental leave to employees to care for and
# bond with a newborn, newly adopted, or newly placed foster child within 12 months of the birth, adoption, or
# state placement of a child; or when required to fulfill the legal requirements for an adoption. parental leave does not apply to situations in which there has been a...
#
# Result 3: distance=0.5333 | file=parental_leave_policy | chunk=3
# hrm-2011– parental leave policy
# university of richmond | 2
# eligibility
# eligible staff and faculty include the mother, father, adoptive parent, or foster parent following the birth,
# adoption, or new placement of a foster child.

# %% [markdown]
# ## Phase 4: Retrieval & Generation
# We implement the custom retrieval logical (with distince threshold filtering) and connect it to AWS Bedrock for the final answer generation.

# %%
# Step 10: Two-Step Retrieval Logic (broad -> narrow)
from typing import Dict, Any

def two_step_retrieve(
    query: str,
    broad_k: int = 25,
    file_k: int = 5,
    final_k: int = 6
) -> Dict[str, Any]:
    """
    1) Broad semantic search across all chunks.
    2) Pick top-N unique files from those hits.
    3) Re-query restricted to those files to get tighter, more on-topic chunks.
    """

    broad = collection.query(
        query_texts=[query],
        n_results=broad_k,
        include=["documents", "metadatas", "distances"]
    )

    hits = []
    for doc, meta, dist in zip(broad["documents"][0], broad["metadatas"][0], broad["distances"][0]):
        hits.append({"text": doc, "meta": meta, "distance": dist})

    # select unique file_name in rank order
    chosen_files = []
    seen = set()
    for h in hits:
        fn = (h["meta"] or {}).get("file_name")
        if fn and fn not in seen:
            chosen_files.append(fn)
            seen.add(fn)
        if len(chosen_files) >= file_k:
            break

    # Narrow search
    if chosen_files:
        narrow = collection.query(
            query_texts=[query],
            n_results=final_k,
            where={"file_name": {"$in": chosen_files}},
            include=["documents", "metadatas", "distances"]
        )
        narrow_hits = []
        for doc, meta, dist in zip(narrow["documents"][0], narrow["metadatas"][0], narrow["distances"][0]):
            narrow_hits.append({"text": doc, "meta": meta, "distance": dist})
    else:
        narrow_hits = hits[:final_k]

    return {
        "query": query,
        "chosen_files": chosen_files,
        "broad_hits": hits,
        "narrow_hits": narrow_hits
    }

# Quick smoke test
q = "Are there policies prohibiting discrimination based on protected status?"
r = two_step_retrieve(q)

print("Query:", r["query"])
print("Chosen files:", r["chosen_files"])
print("\nTop narrow hits:")
for i,h in enumerate(r["narrow_hits"], start=1):
    m = h["meta"] or {}
    print(f"\n{i}. dist={h['distance']:.4f} | file={m.get('file_name')} | chunk={m.get('chunk_part')}")
    print(h["text"][:500] + ("..." if len(h["text"])>500 else ""))
# Out:
# Query: What are the policies regarding drug usage?
# Chosen files: ['alcohol_and_drug_policy', 'hipaa_policy', 'policy_on_prohibiting_and_responding_to_sexual_harassment_and_sexual_misconduct_students', 'health_and_imunization_record_policy']
#
# Top narrow hits:
#
# 1. dist=0.3055 | file=alcohol_and_drug_policy | chunk=8
# these policies encompass
# mandatory drug testing, sanctions as a result of positive drug tests, educational programs relative
# to drug and alcohol use, misuse and counseling.
#
# 2. dist=0.4215 | file=alcohol_and_drug_policy | chunk=41
# sanctions can range from substance education to permanent separation. 1002.5– other drugs policy
# the unauthorized manufacture, distribution and possession of "controlled substances" (illegal
# drugs), including but not limited to cocaine, ecstasy and lsd, are prohibited by both state and
# federal law and are punishable by severe penalties. the university does not tolerate or condone
# such conduct.
#
# 3. dist=0.4222 | file=alcohol_and_drug_policy | chunk=2
# scope:
# the alcohol, tobacco and other drug policy applies to all students, staff, and faculty as well as third party
# users of university facilities. this policy applies to conduct that occurs on the campus of the university, on or
# in off-campus buildings or property of the university and at university sponsored activities, including off-
# campus education programs and activities and public property adjacent to the university. t
# his policy also applies to university students studying abroad throug...
#
# 4. dist=0.4578 | file=alcohol_and_drug_policy | chunk=52
# federal law makes the distribution of "analogue" substances
# marketed for human consumption illegal if those substances are chemically similar to scheduled
# illegal drugs and have the same pharmacological effects on the user. the penalties vary based on
# many factors, including the type and amount of drug involved and whether there is intent to
# distribute. federal law holds that any person who distributes, possesses with intent to distribute, or
# manufactures a controlled substance within one thousa...
#
# 5. dist=0.4880 | file=alcohol_and_drug_policy | chunk=69
#  other drugs
# • possession
# o schedule i or ii drugs – felony- imprisonment from 1 to 10 years or jail for
# up to 12 months and a fine of up to $2,500. o schedule iii drugs – misdemeanor – jail for up to 12 months and a fine up to $2500
# o schedule iv drugs – misdemeanor – jail for up to 6 months and a fine up to $1000
# o schedule v drugs – misdemeanor – fine up to $500
# o schedule vi drugs – misdemeanor – fine up to $250
# • sales/distribution – schedule i or ii drugs
# o felony – imprisonment from 5 to...
#
# 6. dist=0.4922 | file=alcohol_and_drug_policy | chunk=80
# the penalties vary based on the type of
# drug involved, possession and intent to distribute. further information regarding federal penalties can be found at:
# https://www.dea.gov/sites/default/files/drug_of_abuse.pdf#page=30
# (page
# 30-31)
# 1002.78– prevention and education
# the university of richmond uses multiple strategies to provide comprehensive education
# regarding alcohol, tobacco and other drugs. well 100: introduction to college life
# the university of richmond requires all full-time, degree se...

# %%
# Step 11: Final Generation (Bedrock) using Two-Step Retrieval
import json

def _claude_invoke(prompt: str) -> str:
    """Calls Bedrock Claude. Requires valid AWS credentials with Bedrock access."""
    body = {
        "anthropic_version": "bedrock-2023-05-31",
        "max_tokens": 600,
        "temperature": 0.2,
        "messages": [{"role": "user", "content": prompt}],
    }
    resp = bedrock_client.invoke_model(
        modelId=BEDROCK_MODEL_ID,
        body=json.dumps(body),
        accept="application/json",
        contentType="application/json",
    )
    payload = json.loads(resp["body"].read())
    # Claude returns a list of content blocks
    return "".join(block.get("text","") for block in payload.get("content", []))

def generate_answer(query: str) -> str:
    retrieved = two_step_retrieve(query)
    contexts = retrieved["narrow_hits"]

    context_text = "\n\n---\n\n".join(
        f"[Source: {h['meta'].get('file_name')} | chunk {h['meta'].get('chunk_part')}]\n{h['text']}"
        for h in contexts
        if h.get("meta")
    )

    prompt = f"""You are a concise assistant.
Use ONLY the context to answer. If the context is insufficient, say so.
You want to find the answer to the question within the queried data based on the metadata of the files.
Limit the files to only those that are relevant to the question, and then find what specific file has the answer to the question
being asked, so you don't have to search through the entire database. Don't return the file, rather parse the chunk most relevant 
to the question and return the information being asked. You don't need to tell us which chunk the information is coming from, 
simply just return the information being asked as simply as possible.

Here is the context:

Context:
{context_text}

Question: {query}
Answer:"""

    try:
        return _claude_invoke(prompt).strip()
    except Exception as e:
        return f"⚠️ Bedrock call failed ({e}).\n\nHere is the retrieved context you can answer from:\n\n{context_text[:4000]}"

# %%
# Step 12: Final Test
query = "What are the procedures for responding to discrimination based on protected status?"

print(f"❓ Question: {query}\n")
answer = generate_answer(query)

print("💡 Answer:")
print(answer)
# Out:
# ❓ Question: What are the procedures for responding to discrimination based on protected status?
#
# 💡 Answer:
# Based on the context provided, the procedures for responding to discrimination based on protected status involve an investigation and formal resolution process. The key steps mentioned are:
#
# 1. Initial outreach to the complainant.
# 2. Objective evaluation of all relevant evidence, including both inculpatory and exculpatory evidence, by an investigator and decision-maker.
# 3. Determination of whether discrimination occurred based on the relevant evidence.
# 4. Providing notice to the parties with the rationale for the decision.
#
# The formal resolution process is outlined, including details on the investigation stage for staff respondents in the appendices.
